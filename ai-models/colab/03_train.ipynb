# %% [markdown]
# # Training Models
#
# ## 1. Load dữ liệu & Preprocessing
# ## 2. Train/Test Split (80/20, random_state=42)
# ## 3. Baseline Model (DummyRegressor mean)
# ## 4. Linear Regression
# ## 5. Decision Tree Regressor (GridSearchCV)
# ## 6. KNN Regressor (GridSearchCV)
# ## 7. Support Vector Regression - SVR (GridSearchCV)
# ## 8. Hyperparameter Tuning & Cross Validation

# %%
import sys
from pathlib import Path

current_dir = Path.cwd()
project_root = current_dir.parent.parent if current_dir.name == 'colab' else current_dir
ai_models_dir = project_root / 'ai-models'
if str(ai_models_dir) not in sys.path:
    sys.path.insert(0, str(ai_models_dir))

from src.train import train_all_models

trained_pipelines, training_info, (X_train, X_test, y_train, y_test) = train_all_models()
print('Training all 4 models completed successfully!')
# Out:
# === BAT DAU QUY TRINH HUAN LUYEN MODEL ===
# 1. Loading raw dataset...
# 2. Phan chia Train/Test set (80/20)...
#    X_train shape: (21598, 7), X_test shape: (5400, 7)
# 3. Training Baseline Model (DummyRegressor mean)...
# 4. Training Model 1/4: Linear Regression...
#    Linear Regression completed in 0.20s
# 5. Training Model 2/4: Decision Tree Regressor (GridSearchCV)...
#    Decision Tree completed in 35.54s. Best MAE CV: 0.4888
# 6. Training Model 3/4: K-Nearest Neighbors Regressor (GridSearchCV)...
#    KNN completed in 56.69s. Best MAE CV: 0.4690
# 7. Training Model 4/4: Support Vector Regression - SVR (GridSearchCV)...
#    SVR completed in 341.97s. Best MAE CV: 0.4370
# === HOAN THANH QUY TRINH HUAN LUYEN 4 MODEL ===
# Training all 4 models completed successfully!
